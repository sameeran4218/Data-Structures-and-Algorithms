# %% [markdown]
# # Binary Trees

# %%
# How to create a binary tree

class BT:
    def __init__(self,val):
        self.left=None
        self.right=None
        self.val=val
root=BT(1)
child1=BT(2)
child2=BT(3)
root.left=child1
root.right=child2

# %%
# Preorder Traversal

def preorder(root):
    if not root:
        return 
    print(root.val)
    preorder(root.left)
    preorder(root.right)
preorder(root)

# %%
# Inorder Traversal

def inorder(root):
    if not root:
        return
    inorder(root.left)
    print(root.val)
    inorder(root.right)
inorder(root)

# %%
# Postorder Traversal

def postorder(root):
    if not root:
        return 
    postorder(root.left)
    postorder(root.right)
    print(root.val)
postorder(root)

# %%
# Breadth First Search  - return result grouped level-wise

from collections import deque
def BFS(root):
    if not root:
        return []
    q=deque([root])
    ans=[]
    while q:
        level=[]
        for _ in range(len(q)):
            node=q.popleft()
            level.append(node.val)
            if node.left:
                q.append(node.left)
            if node.right:
                q.append(node.right)
        ans.append(level)
    return ans

# %%
# Iterative Preorder Traversal

from collections import deque
class Solution:
    def preorderTraversal(root):
        if not root:
            return []
        ans=[]
        stack=deque([root])
        while stack:
            ele=stack.pop()
            ans.append(ele.val)
            if ele.right:
                stack.append(ele.right)
            if ele.left:
                stack.append(ele.left)    
        return ans

# %%
# Iterative Inorder Traversal

from collections import deque
class Solution:
    def inorderTraversal(root):
        stack=deque()
        ans=[]
        while True:
            if root:
                stack.append(root)
                root=root.left
            else:
                if not stack:
                    break
                ele=stack.pop()
                ans.append(ele.val)
                root=ele.right
        return ans

# %%
# Iterative Postorder Traversal - 2 stacks

from collections import deque
class Solution:
    def postorderTraversal(root):
        if not root:
            return []
        ans=[]
        st1=deque([root])
        st2=deque()
        while st1:
            ele=st1.pop()
            st2.append(ele)
            if ele.left:
                st1.append(ele.left)
            if ele.right:
                st1.append(ele.right)
        while st2:
            ele=st2.pop()
            ans.append(ele.val)
        return ans

# %%
# Iterative Postorder Traversal - 1 stack

from collections import deque
class Solution:
    def postorderTraversal(root):
        if not root:
            return []
        ans=[]
        st=deque()
        while root or st:
            if root:
                st.append(root)
                root=root.left
            else:
                temp=st[-1].right
                if temp:
                    root=temp
                else:
                   temp=st.pop()
                   ans.append(temp.val)
                   while st and temp==st[-1].right:
                        temp=st.pop()
                        ans.append(temp.val)
        return ans

# %%
# Height of Binary Tree
# height of a given node is 1 + max height of nodes to left and nodes to right

def maxDepth(root):
    def height(root):
        if not root:
            return 0
        temp1=height(root.left)
        temp2=height(root.right)
        return 1+max(temp1,temp2)
    return height(root)

# %%
# Height Balanced Tree
# depth of two subtrees of each node doesnt differ by more than 1

def isBalanced(root):
    def height(root):
        if not root:
            return 0
        leftht=height(root.left)
        rightht=height(root.right)
        if abs(leftht-rightht)>1 or leftht<0 or rightht<0:
            return -1
        return 1+max(leftht,rightht)
    return height(root)>=0

# %%
# Diameter of Binary Tree - max distance between any two nodes

class Solution:
    def height(self,root,dia):
        if not root:
            return 0
        lh=self.height(root.left,dia)
        rh=self.height(root.right,dia)
        dia[0]=max(dia[0],lh+rh)
        return 1+max(lh,rh)
    def diameterOfBinaryTree(self,root):
        dia=[0]
        self.height(root,dia)
        return dia[0]

# %%
# Zig Zag Traversal of Binary Tree

from collections import deque
class Solution:
    def zigzagLevelOrder(root):
        if not root:
            return []
        ans=[]
        cnt=0
        q=deque([root])
        while q:
            levels=[]
            sz=len(q)
            for i in range(sz):
                ele=q.popleft()
                levels.append(ele.val)
                if ele.left:
                    q.append(ele.left)
                if ele.right:
                    q.append(ele.right)
            if cnt%2==0:
                ans.append(levels) 
            else:
                ans.append(levels[::-1]) # reverse order for odd cnt
            cnt+=1
        return ans

# %%
# Check if two trees are identical

def isSameTree(p,q):
    def preorder(p,q):
        if not p and not q:
            return True
        if not p or not q:
            return False
        if p.val!=q.val:
            return False
        return preorder(p.left,q.left) and preorder(p.right,q.right)
    return preorder(p,q)

# %%
# Invert a binary tree about its vertical axis
def invert(root):
    if not root:
        return
    root.left,root.right=root.right,root.left
    invert(root.left)
    invert(root.right)

# %%
# Check if a binary tree is mirror of itself about the vertical axis
def isSymmetric(root):
    def mirror(p,q):
        if not p and not q:
            return True
        if not p or not q:
            return False
        return p.val==q.val and mirror(p.left,q.right) and mirror(p.right,q.left)
    return mirror(root.left,root.right)

# %%
# Vertical order traversal of binary tree - return nodes in ascending order of occurence along x-axis
from collections import defaultdict
class Solution:
    def verticalTraversal(self, root: Optional[TreeNode]) -> List[List[int]]:
        hash = defaultdict(list)
        queue = deque([(root, 0, 0)])
        res = []
        while (queue):
            node, hd, depth = queue.popleft()
            hash[hd].append([depth, node.val])

            if node.left:
                queue.append((node.left, hd - 1, depth + 1))
            if node.right:
                queue.append((node.right, hd + 1, depth + 1))
        for i in sorted(hash.keys()):
            temp = []
            for j in sorted(hash[i]):
                temp.append(j[1])
            res.append(temp)
        return res

# %%
# Top View of Binary Tree - only return nodes of tree as seen from the top
# Use similar approach for Bottom View 
from collections import deque
    #Function to return a list of nodes visible from the top view 
    #from left to right in Binary Tree.
def topView(self,root):
    # code 
    mp={}
    q=deque([(root,0,0)])
    while q:
        sz=len(q)
        for _ in range(sz):
            node,col,row=q.popleft()
            if col not in mp or row<mp[col][1]:  # instead of appending all nodes on a col, just update to store the uppermost level
                mp[col]=([node.data,row])
            if node.left:
                q.append((node.left,col-1,row+1))
            if node.right:
                q.append((node.right,col+1,row+1))
    res=[]
    for key in sorted(mp.keys()):
        res.append(mp[key][0])
    return res

# %%
# Right Side/ Left Side View of Binary Tree
# no need to create a dictionary. just check for the last/first encountered node in level order traversal
from collections import deque
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        if not root:
            return []
        res=[]
        mp={}
        q=deque([root])
        while q:
            sz=len(q)
            for i in range(sz):
                node=q.popleft()
                if i==sz-1:
                    res.append(node.val)
                if node.left:
                    q.append(node.left)
                if node.right:
                    q.append(node.right)
        return res

# %%
# Boundary Traversal of Binary Tree
# First add left boundary, then add leaf nodes using preorder traversal , then add reversed right boundary

from collections import deque
class Solution:
    def __init__(self):
        self.res=[]
    def boundaryTraversal(self, root):
        def isLeaf(node):
            if not node.left and not node.right:
                return True
            return False
        def leftBoundary(node):
            curr=node.left
            while curr:
                if not isLeaf(curr):
                    self.res.append(curr.data)
                if curr.left:
                    curr=curr.left
                else:
                    curr=curr.right
            return
        def rightBoundary(node):
            curr=node.right
            st=deque()
            while curr:
                if not isLeaf(curr):
                    st.append(curr.data)
                if curr.right:
                    curr=curr.right
                else:
                    curr=curr.left
            while st:
                self.res.append(st.pop())
            return 
        def leafNodes(node):  # Preorder traversal to check for leaf nodes
            if isLeaf(node):
                self.res.append(node.data)
                return
            if node.left:
                leafNodes(node.left)
            if node.right:
                leafNodes(node.right)
        if not root:
            return
        if not isLeaf(root):
            self.res.append(root.data)
        leftBoundary(root)
        leafNodes(root)
        rightBoundary(root)
        return self.res

# %%
# Given a Binary Tree, you need to find all the possible paths from the root node to all the leaf nodes of the binary tree.
# to reach the leaf nodes use Preorder Traversal and keep storing the path 
class Solution:
    def __init__(self):
        self.res=[]
    def Paths(self, root):
        def isLeaf(root):
            if not root.left and not root.right:
                return True
            return False
        def preorder(root,path):
            if not root:
                return
            path.append(root.data)
            if isLeaf(root):
                self.res.append(path[:])
            preorder(root.left,path)
            preorder(root.right,path)
            path.pop() # backtrack 
        preorder(root,[])
        return self.res
